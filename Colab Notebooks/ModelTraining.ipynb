# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **IMPORTING LIBRARIES**

# %%
import pandas as pd
import numpy as np
import os
from natsort import natsorted
import joblib

# %% [markdown]
# ### **WORKING ON COMBING MULTIPLE LEAD FILES**

# %%
#creating list to store file_names
NORMAL_=[]
MI_=[]
PMI_=[]
HB_=[]

normal = '/content/drive/MyDrive/CardioVision/DataSet/NHB'
abnormal = '/content/drive/MyDrive/CardioVision/DataSet/AHB'
MI = '/content/drive/MyDrive/CardioVision/DataSet/MI'
MI_history = '/content/drive/MyDrive/CardioVision/DataSet/PMI'

Types_ECG = {'normal':normal,'Abnormal_hear_beat':abnormal,'MI':MI,'History_MI':MI_history}

for types,folder in Types_ECG.items():
  for files in os.listdir(folder):
    if types=='normal':
      NORMAL_.append(files)
    elif types=='Abnormal_hear_beat':
      HB_.append(files)
    elif types=='MI':
      MI_.append(files)
    elif types=='History_MI':
      PMI_.append(files)

# %%
NORMAL_ = natsorted(NORMAL_)
NORMAL_
# Out:
# ['Normal(1)',
#  'Normal(1).jpg',
#  'Normal(2)',
#  'Normal(2).jpg',
#  'Normal(3)',
#  'Normal(3).jpg',
#  'Normal(4)',
#  'Normal(4).jpg',
#  'Normal(5)',
#  'Normal(5).jpg',
#  'Normal(6)',
#  'Normal(6).jpg',
#  'Normal(7)',
#  'Normal(7).jpg',
#  'Normal(8)',
#  'Normal(8).jpg',
#  'Normal(9)',
#  'Normal(9).jpg',
#  'Normal(10)',
#  'Normal(10).jpg',
#  'Normal(11)',
#  'Normal(11).jpg',
#  'Normal(12)',
#  'Normal(12).jpg',
#  'Normal(13)',
#  'Normal(13).jpg',
#  'Normal(14)',
#  'Normal(14).jpg',
#  'Normal(15)',
#  'Normal(15).jpg',
#  'Normal(16)',
#  'Normal(16).jpg',
#  'Normal(17)',
#  'Normal(17).jpg',
#  'Normal(18)',
#  'Normal(18).jpg',
#  'Normal(19)',
#  'Normal(19).jpg',
#  'Normal(20)',
#  'Normal(20).jpg',
#  'Normal(21)',
#  'Normal(21).jpg',
#  'Normal(22)',
#  'Normal(22).jpg',
#  'Normal(23)',
#  'Normal(23).jpg',
#  'Normal(24)',
#  'Normal(24).jpg',
#  'Normal(25)',
#  'Normal(25).jpg',
#  'Normal(26)',
#  'Normal(26).jpg',
#  'Normal(27)',
#  'Normal(27).jpg',
#  'Normal(28)',
#  'Normal(28).jpg',
#  'Normal(29)',
#  'Normal(29).jpg',
#  'Normal(30)',
#  'Normal(30).jpg',
#  'Normal(31)',
#  'Normal(31).jpg',
#  'Normal(32)',
#  'Normal(32).jpg',
#  'Normal(33)',
#  'Normal(33).jpg',
#  'Normal(34)',
#  'Normal(34).jpg',
#  'Normal(35)',
#  'Normal(35).jpg',
#  'Normal(36)',
#  'Normal(36).jpg',
#  'Normal(37)',
#  'Normal(37).jpg',
#  'Normal(38)',
#  'Normal(38).jpg',
#  'Normal(39)',
#  'Normal(39).jpg',
#  'Normal(40)',
#  'Normal(40).jpg',
#  'Normal(41)',
#  'Normal(41).jpg',
#  'Normal(42)',
#  'Normal(42).jpg',
#  'Normal(43)',
#  'Normal(43).jpg',
#  'Normal(44)',
#  'Normal(44).jpg',
#  'Normal(45)',
#  'Normal(45).jpg',
#  'Normal(46)',
#  'Normal(46).jpg',
#  'Normal(47)',
#  'Normal(47).jpg',
#  'Normal(48)',
#  'Normal(48).jpg',
#  'Normal(49)',
#  'Normal(49).jpg',
#  'Normal(50)',
#  'Normal(50).jpg',
#  'Normal(51)',
#  'Normal(51).jpg',
#  'Normal(52)',
#  'Normal(52).jpg',
#  'Normal(53)',
#  'Normal(53).jpg',
#  'Normal(54)',
#  'Normal(54).jpg',
#  'Normal(55)',
#  'Normal(55).jpg',
#  'Normal(56)',
#  'Normal(56).jpg',
#  'Normal(57)',
#  'Normal(57).jpg',
#  'Normal(58)',
#  'Normal(58).jpg',
#  'Normal(59)',
#  'Normal(59).jpg',
#  'Normal(60)',
#  'Normal(60).jpg',
#  'Normal(61)',
#  'Normal(61).jpg',
#  'Normal(62)',
#  'Normal(62).jpg',
#  'Normal(63)',
#  'Normal(63).jpg',
#  'Normal(64)',
#  'Normal(64).jpg',
#  'Normal(65)',
#  'Normal(65).jpg',
#  'Normal(66)',
#  'Normal(66).jpg',
#  'Normal(67)',
#  'Normal(67).jpg',
#  'Normal(68)',
#  'Normal(68).jpg',
#  'Normal(69)',
#  'Normal(69).jpg',
#  'Normal(70)',
#  'Normal(70).jpg',
#  'Normal(71)',
#  'Normal(71).jpg',
#  'Normal(72)',
#  'Normal(72).jpg',
#  'Normal(73)',
#  'Normal(73).jpg',
#  'Normal(74)',
#  'Normal(74).jpg',
#  'Normal(75)',
#  'Normal(75).jpg',
#  'Normal(76)',
#  'Normal(76).jpg',
#  'Normal(77)',
#  'Normal(77).jpg',
#  'Normal(78)',
#  'Normal(78).jpg',
#  'Normal(79)',
#  'Normal(79).jpg',
#  'Normal(80)',
#  'Normal(80).jpg',
#  'Normal(81)',
#  'Normal(81).jpg',
#  'Normal(82)',
#  'Normal(82).jpg',
#  'Normal(83)',
#  'Normal(83).jpg',
#  'Normal(84)',
#  'Normal(84).jpg',
#  'Normal(85)',
#  'Normal(85).jpg',
#  'Normal(86)',
#  'Normal(86).jpg',
#  'Normal(87)',
#  'Normal(87).jpg',
#  'Normal(88)',
#  'Normal(88).jpg',
#  'Normal(89)',
#  'Normal(89).jpg',
#  'Normal(90)',
#  'Normal(90).jpg',
#  'Normal(91)',
#  'Normal(91).jpg',
#  'Normal(92)',
#  'Normal(92).jpg',
#  'Normal(93)',
#  'Normal(93).jpg',
#  'Normal(94)',
#  'Normal(94).jpg',
#  'Normal(95)',
#  'Normal(95).jpg',
#  'Normal(96)',
#  'Normal(96).jpg',
#  'Normal(97)',
#  'Normal(97).jpg',
#  'Normal(98)',
#  'Normal(98).jpg',
#  'Normal(99)',
#  'Normal(99).jpg',
#  'Normal(100)',
#  'Normal(100).jpg',
#  'Normal(101)',
#  'Normal(101).jpg',
#  'Normal(102)',
#  'Normal(102).jpg',
#  'Normal(103)',
#  'Normal(103).jpg',
#  'Normal(104)',
#  'Normal(104).jpg',
#  'Normal(105)',
#  'Normal(105).jpg',
#  'Normal(106)',
#  'Normal(106).jpg',
#  'Normal(107)',
#  'Normal(107).jpg',
#  'Normal(108)',
#  'Normal(108).jpg',
#  'Normal(109)',
#  'Normal(109).jpg',
#  'Normal(110)',
#  'Normal(110).jpg',
#  'Normal(111)',
#  'Normal(111).jpg',
#  'Normal(112)',
#  'Normal(112).jpg',
#  'Normal(113)',
#  'Normal(113).jpg',
#  'Normal(114)',
#  'Normal(114).jpg',
#  'Normal(115)',
#  'Normal(115).jpg',
#  'Normal(116)',
#  'Normal(116).jpg',
#  'Normal(117)',
#  'Normal(117).jpg',
#  'Normal(118)',
#  'Normal(118).jpg',
#  'Normal(119)',
#  'Normal(119).jpg',
#  'Normal(120)',
#  'Normal(120).jpg',
#  'Normal(121)',
#  'Normal(121).jpg',
#  'Normal(122)',
#  'Normal(122).jpg',
#  'Normal(123)',
#  'Normal(123).jpg',
#  'Normal(124)',
#  'Normal(124).jpg',
#  'Normal(125)',
#  'Normal(125).jpg',
#  'Normal(126)',
#  'Normal(126).jpg',
#  'Normal(127)',
#  'Normal(127).jpg',
#  'Normal(128)',
#  'Normal(128).jpg',
#  'Normal(129)',
#  'Normal(129).jpg',
#  'Normal(130)',
#  'Normal(130).jpg',
#  'Normal(131)',
#  'Normal(131).jpg',
#  'Normal(132)',
#  'Normal(132).jpg',
#  'Normal(133)',
#  'Normal(133).jpg',
#  'Normal(134)',
#  'Normal(134).jpg',
#  'Normal(135)',
#  'Normal(135).jpg',
#  'Normal(136)',
#  'Normal(136).jpg',
#  'Normal(137)',
#  'Normal(137).jpg',
#  'Normal(138)',
#  'Normal(138).jpg',
#  'Normal(139)',
#  'Normal(139).jpg',
#  'Normal(140)',
#  'Normal(140).jpg',
#  'Normal(141)',
#  'Normal(141).jpg',
#  'Normal(142)',
#  'Normal(142).jpg',
#  'Normal(143)',
#  'Normal(143).jpg',
#  'Normal(144)',
#  'Normal(144).jpg',
#  'Normal(145)',
#  'Normal(145).jpg',
#  'Normal(146)',
#  'Normal(146).jpg',
#  'Normal(147)',
#  'Normal(147).jpg',
#  'Normal(148)',
#  'Normal(148).jpg',
#  'Normal(149)',
#  'Normal(149).jpg',
#  'Normal(150)',
#  'Normal(150).jpg',
#  'Normal(151)',
#  'Normal(151).jpg',
#  'Normal(152)',
#  'Normal(152).jpg',
#  'Normal(153)',
#  'Normal(153).jpg',
#  'Normal(154)',
#  'Normal(154).jpg',
#  'Normal(155)',
#  'Normal(155).jpg',
#  'Normal(156)',
#  'Normal(156).jpg',
#  'Normal(157)',
#  'Normal(157).jpg',
#  'Normal(158)',
#  'Normal(158).jpg',
#  'Normal(159)',
#  'Normal(159).jpg',
#  'Normal(160)',
#  'Normal(160).jpg',
#  'Normal(161)',
#  'Normal(161).jpg',
#  'Normal(162)',
#  'Normal(162).jpg',
#  'Normal(163)',
#  'Normal(163).jpg',
#  'Normal(164)',
#  'Normal(164).jpg',
#  'Normal(165)',
#  'Normal(165).jpg',
#  'Normal(166)',
#  'Normal(166).jpg',
#  'Normal(167)',
#  'Normal(167).jpg',
#  'Normal(168)',
#  'Normal(168).jpg',
#  'Normal(169)',
#  'Normal(169).jpg',
#  'Normal(170)',
#  'Normal(170).jpg',
#  'Normal(171)',
#  'Normal(171).jpg',
#  'Normal(172)',
#  'Normal(172).jpg',
#  'Normal(173)',
#  'Normal(173).jpg',
#  'Normal(174)',
#  'Normal(174).jpg',
#  'Normal(175)',
#  'Normal(175).jpg',
#  'Normal(176)',
#  'Normal(176).jpg',
#  'Normal(177)',
#  'Normal(177).jpg',
#  'Normal(178)',
#  'Normal(178).jpg',
#  'Normal(179)',
#  'Normal(179).jpg',
#  'Normal(180)',
#  'Normal(180).jpg',
#  'Normal(181)',
#  'Normal(181).jpg',
#  'Normal(182)',
#  'Normal(182).jpg',
#  'Normal(183)',
#  'Normal(183).jpg',
#  'Normal(184)',
#  'Normal(184).jpg',
#  'Normal(185)',
#  'Normal(185).jpg',
#  'Normal(186)',
#  'Normal(186).jpg',
#  'Normal(187)',
#  'Normal(187).jpg',
#  'Normal(188)',
#  'Normal(188).jpg',
#  'Normal(189)',
#  'Normal(189).jpg',
#  'Normal(190)',
#  'Normal(190).jpg',
#  'Normal(191)',
#  'Normal(191).jpg',
#  'Normal(192)',
#  'Normal(192).jpg',
#  'Normal(193)',
#  'Normal(193).jpg',
#  'Normal(194)',
#  'Normal(194).jpg',
#  'Normal(195)',
#  'Normal(195).jpg',
#  'Normal(196)',
#  'Normal(196).jpg',
#  'Normal(197)',
#  'Normal(197).jpg',
#  'Normal(198)',
#  'Normal(198).jpg',
#  'Normal(199)',
#  'Normal(199).jpg',
#  'Normal(200)',
#  'Normal(200).jpg',
#  'Normal(201)',
#  'Normal(201).jpg',
#  'Normal(202)',
#  'Normal(202).jpg',
#  'Normal(203)',
#  'Normal(203).jpg',
#  'Normal(204)',
#  'Normal(204).jpg',
#  'Normal(205)',
#  'Normal(205).jpg',
#  'Normal(206)',
#  'Normal(206).jpg',
#  'Normal(207)',
#  'Normal(207).jpg',
#  'Normal(208)',
#  'Normal(208).jpg',
#  'Normal(209)',
#  'Normal(209).jpg',
#  'Normal(210)',
#  'Normal(210).jpg',
#  'Normal(211)',
#  'Normal(211).jpg',
#  'Normal(212)',
#  'Normal(212).jpg',
#  'Normal(213)',
#  'Normal(213).jpg',
#  'Normal(214)',
#  'Normal(214).jpg',
#  'Normal(215)',
#  'Normal(215).jpg',
#  'Normal(216)',
#  'Normal(216).jpg',
#  'Normal(217)',
#  'Normal(217).jpg',
#  'Normal(218)',
#  'Normal(218).jpg',
#  'Normal(219)',
#  'Normal(219).jpg',
#  'Normal(220)',
#  'Normal(220).jpg',
#  'Normal(221)',
#  'Normal(221).jpg',
#  'Normal(222)',
#  'Normal(222).jpg',
#  'Normal(223)',
#  'Normal(223).jpg',
#  'Normal(224)',
#  'Normal(224).jpg',
#  'Normal(225)',
#  'Normal(225).jpg',
#  'Normal(226)',
#  'Normal(226).jpg',
#  'Normal(227)',
#  'Normal(227).jpg',
#  'Normal(228)',
#  'Normal(228).jpg',
#  'Normal(229)',
#  'Normal(229).jpg',
#  'Normal(230)',
#  'Normal(230).jpg',
#  'Normal(231)',
#  'Normal(231).jpg',
#  'Normal(232)',
#  'Normal(232).jpg',
#  'Normal(233)',
#  'Normal(233).jpg',
#  'Normal(234)',
#  'Normal(234).jpg',
#  'Normal(235)',
#  'Normal(235).jpg',
#  'Normal(236)',
#  'Normal(236).jpg',
#  'Normal(237)',
#  'Normal(237).jpg',
#  'Normal(238)',
#  'Normal(238).jpg',
#  'Normal(239)',
#  'Normal(239).jpg',
#  'Normal(240)',
#  'Normal(240).jpg',
#  'Normal(241)',
#  'Normal(241).jpg',
#  'Normal(242)',
#  'Normal(242).jpg',
#  'Normal(243)',
#  'Normal(243).jpg',
#  'Normal(244)',
#  'Normal(244).jpg',
#  'Normal(245)',
#  'Normal(245).jpg',
#  'Normal(246)',
#  'Normal(246).jpg',
#  'Normal(247)',
#  'Normal(247).jpg',
#  'Normal(248)',
#  'Normal(248).jpg',
#  'Normal(249)',
#  'Normal(249).jpg',
#  'Normal(250)',
#  'Normal(250).jpg',
#  'Normal(251)',
#  'Normal(251).jpg',
#  'Normal(252)',
#  'Normal(252).jpg',
#  'Normal(253)',
#  'Normal(253).jpg',
#  'Normal(254)',
#  'Normal(254).jpg',
#  'Normal(255)',
#  'Normal(255).jpg',
#  'Normal(256)',
#  'Normal(256).jpg',
#  'Normal(257)',
#  'Normal(257).jpg',
#  'Normal(258)',
#  'Normal(258).jpg',
#  'Normal(259)',
#  'Normal(259).jpg',
#  'Normal(260)',
#  'Normal(260).jpg',
#  'Normal(261)',
#  'Normal(261).jpg',
#  'Normal(262)',
#  'Normal(262).jpg',
#  'Normal(263)',
#  'Normal(263).jpg',
#  'Normal(264)',
#  'Normal(264).jpg',
#  'Normal(265)',
#  'Normal(265).jpg',
#  'Normal(266)',
#  'Normal(266).jpg',
#  'Normal(267)',
#  'Normal(267).jpg',
#  'Normal(268)',
#  'Normal(268).jpg',
#  'Normal(269)',
#  'Normal(269).jpg',
#  'Normal(270)',
#  'Normal(270).jpg',
#  'Normal(271)',
#  'Normal(271).jpg',
#  'Normal(272)',
#  'Normal(272).jpg',
#  'Normal(273)',
#  'Normal(273).jpg',
#  'Normal(274)',
#  'Normal(274).jpg',
#  'Normal(275)',
#  'Normal(275).jpg',
#  'Normal(276)',
#  'Normal(276).jpg',
#  'Normal(277)',
#  'Normal(277).jpg',
#  'Normal(278)',
#  'Normal(278).jpg',
#  'Normal(279)',
#  'Normal(279).jpg',
#  'Normal(280)',
#  'Normal(280).jpg',
#  'Normal(281)',
#  'Normal(281).jpg',
#  'Normal(282)',
#  'Normal(282).jpg',
#  'Normal(283)',
#  'Normal(283).jpg',
#  'Normal(284)',
#  'Normal(284).jpg',
#  'scaled_data_1D_1.csv',
#  'scaled_data_1D_2.csv',
#  'scaled_data_1D_3.csv',
#  'scaled_data_1D_4.csv',
#  'scaled_data_1D_5.csv',
#  'scaled_data_1D_6.csv',
#  'scaled_data_1D_7.csv',
#  'scaled_data_1D_8.csv',
#  'scaled_data_1D_9.csv',
#  'scaled_data_1D_10.csv',
#  'scaled_data_1D_11.csv',
#  'scaled_data_1D_12.csv',
#  'scaled_data_1D_13.csv']

# %%
MI_ = natsorted(MI_)
MI_
# Out:
# ['MI(1)',
#  'MI(1).jpg',
#  'MI(2)',
#  'MI(2).jpg',
#  'MI(3)',
#  'MI(3).jpg',
#  'MI(4)',
#  'MI(4).jpg',
#  'MI(5)',
#  'MI(5).jpg',
#  'MI(6)',
#  'MI(6).jpg',
#  'MI(7)',
#  'MI(7).jpg',
#  'MI(8)',
#  'MI(8).jpg',
#  'MI(9)',
#  'MI(9).jpg',
#  'MI(10)',
#  'MI(10).jpg',
#  'MI(11)',
#  'MI(11).jpg',
#  'MI(12)',
#  'MI(12).jpg',
#  'MI(13)',
#  'MI(13).jpg',
#  'MI(14)',
#  'MI(14).jpg',
#  'MI(15)',
#  'MI(15).jpg',
#  'MI(16)',
#  'MI(16).jpg',
#  'MI(17)',
#  'MI(17).jpg',
#  'MI(18)',
#  'MI(18).jpg',
#  'MI(19)',
#  'MI(19).jpg',
#  'MI(20)',
#  'MI(20).jpg',
#  'MI(21)',
#  'MI(21).jpg',
#  'MI(22)',
#  'MI(22).jpg',
#  'MI(23)',
#  'MI(23).jpg',
#  'MI(24)',
#  'MI(24).jpg',
#  'MI(25)',
#  'MI(25).jpg',
#  'MI(26)',
#  'MI(26).jpg',
#  'MI(27)',
#  'MI(27).jpg',
#  'MI(28)',
#  'MI(28).jpg',
#  'MI(29)',
#  'MI(29).jpg',
#  'MI(30)',
#  'MI(30).jpg',
#  'MI(31)',
#  'MI(31).jpg',
#  'MI(32)',
#  'MI(32).jpg',
#  'MI(33)',
#  'MI(33).jpg',
#  'MI(34)',
#  'MI(34).jpg',
#  'MI(35)',
#  'MI(35).jpg',
#  'MI(36)',
#  'MI(36).jpg',
#  'MI(37)',
#  'MI(37).jpg',
#  'MI(38)',
#  'MI(38).jpg',
#  'MI(39)',
#  'MI(39).jpg',
#  'MI(40)',
#  'MI(40).jpg',
#  'MI(41)',
#  'MI(41).jpg',
#  'MI(42)',
#  'MI(42).jpg',
#  'MI(43)',
#  'MI(43).jpg',
#  'MI(44)',
#  'MI(44).jpg',
#  'MI(45)',
#  'MI(45).jpg',
#  'MI(46)',
#  'MI(46).jpg',
#  'MI(47)',
#  'MI(47).jpg',
#  'MI(48)',
#  'MI(48).jpg',
#  'MI(49)',
#  'MI(49).jpg',
#  'MI(50)',
#  'MI(50).jpg',
#  'MI(51)',
#  'MI(51).jpg',
#  'MI(52)',
#  'MI(52).jpg',
#  'MI(53)',
#  'MI(53).jpg',
#  'MI(54)',
#  'MI(54).jpg',
#  'MI(55)',
#  'MI(55).jpg',
#  'MI(56)',
#  'MI(56).jpg',
#  'MI(57)',
#  'MI(57).jpg',
#  'MI(58)',
#  'MI(58).jpg',
#  'MI(59)',
#  'MI(59).jpg',
#  'MI(60)',
#  'MI(60).jpg',
#  'MI(61)',
#  'MI(61).jpg',
#  'MI(62)',
#  'MI(62).jpg',
#  'MI(63)',
#  'MI(63).jpg',
#  'MI(64)',
#  'MI(64).jpg',
#  'MI(65)',
#  'MI(65).jpg',
#  'MI(66)',
#  'MI(66).jpg',
#  'MI(67)',
#  'MI(67).jpg',
#  'MI(68)',
#  'MI(68).jpg',
#  'MI(69)',
#  'MI(69).jpg',
#  'MI(70)',
#  'MI(70).jpg',
#  'MI(71)',
#  'MI(71).jpg',
#  'MI(72)',
#  'MI(72).jpg',
#  'MI(73)',
#  'MI(73).jpg',
#  'MI(74)',
#  'MI(74).jpg',
#  'MI(75)',
#  'MI(75).jpg',
#  'MI(76)',
#  'MI(76).jpg',
#  'MI(77)',
#  'MI(77).jpg',
#  'MI(78)',
#  'MI(78).jpg',
#  'MI(79)',
#  'MI(79).jpg',
#  'MI(80)',
#  'MI(80).jpg',
#  'MI(81)',
#  'MI(81).jpg',
#  'MI(82)',
#  'MI(82).jpg',
#  'MI(83)',
#  'MI(83).jpg',
#  'MI(84)',
#  'MI(84).jpg',
#  'MI(85)',
#  'MI(85).jpg',
#  'MI(86)',
#  'MI(86).jpg',
#  'MI(87)',
#  'MI(87).jpg',
#  'MI(88)',
#  'MI(88).jpg',
#  'MI(89)',
#  'MI(89).jpg',
#  'MI(90)',
#  'MI(90).jpg',
#  'MI(91)',
#  'MI(91).jpg',
#  'MI(92)',
#  'MI(92).jpg',
#  'MI(93)',
#  'MI(93).jpg',
#  'MI(94)',
#  'MI(94).jpg',
#  'MI(95)',
#  'MI(95).jpg',
#  'MI(96)',
#  'MI(96).jpg',
#  'MI(97)',
#  'MI(97).jpg',
#  'MI(98)',
#  'MI(98).jpg',
#  'MI(99)',
#  'MI(99).jpg',
#  'MI(100)',
#  'MI(100).jpg',
#  'MI(101)',
#  'MI(101).jpg',
#  'MI(102)',
#  'MI(102).jpg',
#  'MI(103)',
#  'MI(103).jpg',
#  'MI(104)',
#  'MI(104).jpg',
#  'MI(105)',
#  'MI(105).jpg',
#  'MI(106)',
#  'MI(106).jpg',
#  'MI(107)',
#  'MI(107).jpg',
#  'MI(108)',
#  'MI(108).jpg',
#  'MI(109)',
#  'MI(109).jpg',
#  'MI(110)',
#  'MI(110).jpg',
#  'MI(111)',
#  'MI(111).jpg',
#  'MI(112)',
#  'MI(112).jpg',
#  'MI(113)',
#  'MI(113).jpg',
#  'MI(114)',
#  'MI(114).jpg',
#  'MI(115)',
#  'MI(115).jpg',
#  'MI(116)',
#  'MI(116).jpg',
#  'MI(117)',
#  'MI(117).jpg',
#  'MI(118)',
#  'MI(118).jpg',
#  'MI(119)',
#  'MI(119).jpg',
#  'MI(120)',
#  'MI(120).jpg',
#  'MI(121)',
#  'MI(121).jpg',
#  'MI(122)',
#  'MI(122).jpg',
#  'MI(123)',
#  'MI(123).jpg',
#  'MI(124)',
#  'MI(124).jpg',
#  'MI(125)',
#  'MI(125).jpg',
#  'MI(126)',
#  'MI(126).jpg',
#  'MI(127)',
#  'MI(127).jpg',
#  'MI(128)',
#  'MI(128).jpg',
#  'MI(129)',
#  'MI(129).jpg',
#  'MI(130)',
#  'MI(130).jpg',
#  'MI(131)',
#  'MI(131).jpg',
#  'MI(132)',
#  'MI(132).jpg',
#  'MI(133)',
#  'MI(133).jpg',
#  'MI(134)',
#  'MI(134).jpg',
#  'MI(135)',
#  'MI(135).jpg',
#  'MI(136)',
#  'MI(136).jpg',
#  'MI(137)',
#  'MI(137).jpg',
#  'MI(138)',
#  'MI(138).jpg',
#  'MI(139)',
#  'MI(139).jpg',
#  'MI(140)',
#  'MI(140).jpg',
#  'MI(141)',
#  'MI(141).jpg',
#  'MI(142)',
#  'MI(142).jpg',
#  'MI(143)',
#  'MI(143).jpg',
#  'MI(144)',
#  'MI(144).jpg',
#  'MI(145)',
#  'MI(145).jpg',
#  'MI(146)',
#  'MI(146).jpg',
#  'MI(147)',
#  'MI(147).jpg',
#  'MI(148)',
#  'MI(148).jpg',
#  'MI(149)',
#  'MI(149).jpg',
#  'MI(150)',
#  'MI(150).jpg',
#  'MI(151)',
#  'MI(151).jpg',
#  'MI(152)',
#  'MI(152).jpg',
#  'MI(153)',
#  'MI(153).jpg',
#  'MI(154)',
#  'MI(154).jpg',
#  'MI(155)',
#  'MI(155).jpg',
#  'MI(156)',
#  'MI(156).jpg',
#  'MI(157)',
#  'MI(157).jpg',
#  'MI(158)',
#  'MI(158).jpg',
#  'MI(159)',
#  'MI(159).jpg',
#  'MI(160)',
#  'MI(160).jpg',
#  'MI(161)',
#  'MI(161).jpg',
#  'MI(162)',
#  'MI(162).jpg',
#  'MI(163)',
#  'MI(163).jpg',
#  'MI(164)',
#  'MI(164).jpg',
#  'MI(165)',
#  'MI(165).jpg',
#  'MI(166)',
#  'MI(166).jpg',
#  'MI(167)',
#  'MI(167).jpg',
#  'MI(168)',
#  'MI(168).jpg',
#  'MI(169)',
#  'MI(169).jpg',
#  'MI(170)',
#  'MI(170).jpg',
#  'MI(171)',
#  'MI(171).jpg',
#  'MI(172)',
#  'MI(172).jpg',
#  'MI(173)',
#  'MI(173).jpg',
#  'MI(174)',
#  'MI(174).jpg',
#  'MI(175)',
#  'MI(175).jpg',
#  'MI(176)',
#  'MI(176).jpg',
#  'MI(177)',
#  'MI(177).jpg',
#  'MI(178)',
#  'MI(178).jpg',
#  'MI(179)',
#  'MI(179).jpg',
#  'MI(180)',
#  'MI(180).jpg',
#  'MI(181)',
#  'MI(181).jpg',
#  'MI(182)',
#  'MI(182).jpg',
#  'MI(183)',
#  'MI(183).jpg',
#  'MI(184)',
#  'MI(184).jpg',
#  'MI(185)',
#  'MI(185).jpg',
#  'MI(186)',
#  'MI(186).jpg',
#  'MI(187)',
#  'MI(187).jpg',
#  'MI(188)',
#  'MI(188).jpg',
#  'MI(189)',
#  'MI(189).jpg',
#  'MI(190)',
#  'MI(190).jpg',
#  'MI(191)',
#  'MI(191).jpg',
#  'MI(192)',
#  'MI(192).jpg',
#  'MI(193)',
#  'MI(193).jpg',
#  'MI(194)',
#  'MI(194).jpg',
#  'MI(195)',
#  'MI(195).jpg',
#  'MI(196)',
#  'MI(196).jpg',
#  'MI(197)',
#  'MI(197).jpg',
#  'MI(198)',
#  'MI(198).jpg',
#  'MI(199)',
#  'MI(199).jpg',
#  'MI(200)',
#  'MI(200).jpg',
#  'MI(201)',
#  'MI(201).jpg',
#  'MI(202)',
#  'MI(202).jpg',
#  'MI(203)',
#  'MI(203).jpg',
#  'MI(204)',
#  'MI(204).jpg',
#  'MI(205)',
#  'MI(205).jpg',
#  'MI(206)',
#  'MI(206).jpg',
#  'MI(207)',
#  'MI(207).jpg',
#  'MI(208)',
#  'MI(208).jpg',
#  'MI(209)',
#  'MI(209).jpg',
#  'MI(210)',
#  'MI(210).jpg',
#  'MI(211)',
#  'MI(211).jpg',
#  'MI(212)',
#  'MI(212).jpg',
#  'MI(213)',
#  'MI(213).jpg',
#  'MI(214)',
#  'MI(214).jpg',
#  'MI(216)',
#  'MI(216).jpg',
#  'MI(217)',
#  'MI(217).jpg',
#  'MI(218)',
#  'MI(218).jpg',
#  'MI(219)',
#  'MI(219).jpg',
#  'MI(220)',
#  'MI(220).jpg',
#  'MI(221)',
#  'MI(221).jpg',
#  'MI(222)',
#  'MI(222).jpg',
#  'MI(223)',
#  'MI(223).jpg',
#  'MI(224)',
#  'MI(224).jpg',
#  'MI(225)',
#  'MI(225).jpg',
#  'MI(226)',
#  'MI(226).jpg',
#  'MI(227)',
#  'MI(227).jpg',
#  'MI(228)',
#  'MI(228).jpg',
#  'MI(229)',
#  'MI(229).jpg',
#  'MI(230)',
#  'MI(230).jpg',
#  'MI(231)',
#  'MI(231).jpg',
#  'MI(232)',
#  'MI(232).jpg',
#  'MI(233)',
#  'MI(233).jpg',
#  'MI(234)',
#  'MI(234).jpg',
#  'MI(235)',
#  'MI(235).jpg',
#  'MI(236)',
#  'MI(236).jpg',
#  'MI(237)',
#  'MI(237).jpg',
#  'MI(238)',
#  'MI(238).jpg',
#  'MI(239)',
#  'MI(239).jpg',
#  'MI(240)',
#  'MI(240).jpg',
#  'scaled_data_1D_1.csv',
#  'scaled_data_1D_2.csv',
#  'scaled_data_1D_3.csv',
#  'scaled_data_1D_4.csv',
#  'scaled_data_1D_5.csv',
#  'scaled_data_1D_6.csv',
#  'scaled_data_1D_7.csv',
#  'scaled_data_1D_8.csv',
#  'scaled_data_1D_9.csv',
#  'scaled_data_1D_10.csv',
#  'scaled_data_1D_11.csv',
#  'scaled_data_1D_12.csv',
#  'scaled_data_1D_13.csv']

# %%
PMI_ = natsorted(PMI_)
PMI_
# Out:
# ['PMI(1)',
#  'PMI(1).jpg',
#  'PMI(2)',
#  'PMI(2).jpg',
#  'PMI(3)',
#  'PMI(3).jpg',
#  'PMI(4)',
#  'PMI(4).jpg',
#  'PMI(5)',
#  'PMI(5).jpg',
#  'PMI(6)',
#  'PMI(6).jpg',
#  'PMI(7)',
#  'PMI(7).jpg',
#  'PMI(8)',
#  'PMI(8).jpg',
#  'PMI(9)',
#  'PMI(9).jpg',
#  'PMI(10)',
#  'PMI(10).jpg',
#  'PMI(11)',
#  'PMI(11).jpg',
#  'PMI(12)',
#  'PMI(12).jpg',
#  'PMI(13)',
#  'PMI(13).jpg',
#  'PMI(14)',
#  'PMI(14).jpg',
#  'PMI(15)',
#  'PMI(15).jpg',
#  'PMI(16)',
#  'PMI(16).jpg',
#  'PMI(17)',
#  'PMI(17).jpg',
#  'PMI(18)',
#  'PMI(18).jpg',
#  'PMI(19)',
#  'PMI(19).jpg',
#  'PMI(20)',
#  'PMI(20).jpg',
#  'PMI(21)',
#  'PMI(21).jpg',
#  'PMI(22)',
#  'PMI(22).jpg',
#  'PMI(23)',
#  'PMI(23).jpg',
#  'PMI(24)',
#  'PMI(24).jpg',
#  'PMI(25)',
#  'PMI(25).jpg',
#  'PMI(26)',
#  'PMI(26).jpg',
#  'PMI(27)',
#  'PMI(27).jpg',
#  'PMI(28)',
#  'PMI(28).jpg',
#  'PMI(29)',
#  'PMI(29).jpg',
#  'PMI(30)',
#  'PMI(30).jpg',
#  'PMI(31)',
#  'PMI(31).jpg',
#  'PMI(32)',
#  'PMI(32).jpg',
#  'PMI(33)',
#  'PMI(33).jpg',
#  'PMI(34)',
#  'PMI(34).jpg',
#  'PMI(35)',
#  'PMI(35).jpg',
#  'PMI(36)',
#  'PMI(36).jpg',
#  'PMI(37)',
#  'PMI(37).jpg',
#  'PMI(38)',
#  'PMI(38).jpg',
#  'PMI(39)',
#  'PMI(39).jpg',
#  'PMI(40)',
#  'PMI(40).jpg',
#  'PMI(41)',
#  'PMI(41).jpg',
#  'PMI(42)',
#  'PMI(42).jpg',
#  'PMI(43)',
#  'PMI(43).jpg',
#  'PMI(44)',
#  'PMI(44).jpg',
#  'PMI(45)',
#  'PMI(45).jpg',
#  'PMI(46)',
#  'PMI(46).jpg',
#  'PMI(47)',
#  'PMI(47).jpg',
#  'PMI(48)',
#  'PMI(48).jpg',
#  'PMI(49)',
#  'PMI(49).jpg',
#  'PMI(50)',
#  'PMI(50).jpg',
#  'PMI(51)',
#  'PMI(51).jpg',
#  'PMI(52)',
#  'PMI(52).jpg',
#  'PMI(53)',
#  'PMI(53).jpg',
#  'PMI(54)',
#  'PMI(54).jpg',
#  'PMI(55)',
#  'PMI(55).jpg',
#  'PMI(56)',
#  'PMI(56).jpg',
#  'PMI(57)',
#  'PMI(57).jpg',
#  'PMI(58)',
#  'PMI(58).jpg',
#  'PMI(59)',
#  'PMI(59).jpg',
#  'PMI(60)',
#  'PMI(60).jpg',
#  'PMI(61)',
#  'PMI(61).jpg',
#  'PMI(62)',
#  'PMI(62).jpg',
#  'PMI(63)',
#  'PMI(63).jpg',
#  'PMI(64)',
#  'PMI(64).jpg',
#  'PMI(65)',
#  'PMI(65).jpg',
#  'PMI(66)',
#  'PMI(66).jpg',
#  'PMI(67)',
#  'PMI(67).jpg',
#  'PMI(68)',
#  'PMI(68).jpg',
#  'PMI(69)',
#  'PMI(69).jpg',
#  'PMI(70)',
#  'PMI(70).jpg',
#  'PMI(71)',
#  'PMI(71).jpg',
#  'PMI(72)',
#  'PMI(72).jpg',
#  'PMI(73)',
#  'PMI(73).jpg',
#  'PMI(74)',
#  'PMI(74).jpg',
#  'PMI(75)',
#  'PMI(75).jpg',
#  'PMI(76)',
#  'PMI(76).jpg',
#  'PMI(77)',
#  'PMI(77).jpg',
#  'PMI(78)',
#  'PMI(78).jpg',
#  'PMI(79)',
#  'PMI(79).jpg',
#  'PMI(80)',
#  'PMI(80).jpg',
#  'PMI(81)',
#  'PMI(81).jpg',
#  'PMI(82)',
#  'PMI(82).jpg',
#  'PMI(83)',
#  'PMI(83).jpg',
#  'PMI(84)',
#  'PMI(84).jpg',
#  'PMI(85)',
#  'PMI(85).jpg',
#  'PMI(86)',
#  'PMI(86).jpg',
#  'PMI(87)',
#  'PMI(87).jpg',
#  'PMI(88)',
#  'PMI(88).jpg',
#  'PMI(89)',
#  'PMI(89).jpg',
#  'PMI(90)',
#  'PMI(90).jpg',
#  'PMI(91)',
#  'PMI(91).jpg',
#  'PMI(92)',
#  'PMI(92).jpg',
#  'PMI(93)',
#  'PMI(93).jpg',
#  'PMI(94)',
#  'PMI(94).jpg',
#  'PMI(95)',
#  'PMI(95).jpg',
#  'PMI(96)',
#  'PMI(96).jpg',
#  'PMI(97)',
#  'PMI(97).jpg',
#  'PMI(98)',
#  'PMI(98).jpg',
#  'PMI(99)',
#  'PMI(99).jpg',
#  'PMI(100)',
#  'PMI(100).jpg',
#  'PMI(101)',
#  'PMI(101).jpg',
#  'PMI(102)',
#  'PMI(102).jpg',
#  'PMI(103)',
#  'PMI(103).jpg',
#  'PMI(104)',
#  'PMI(104).jpg',
#  'PMI(105)',
#  'PMI(105).jpg',
#  'PMI(106)',
#  'PMI(106).jpg',
#  'PMI(107)',
#  'PMI(107).jpg',
#  'PMI(108)',
#  'PMI(108).jpg',
#  'PMI(109)',
#  'PMI(109).jpg',
#  'PMI(110)',
#  'PMI(110).jpg',
#  'PMI(111)',
#  'PMI(111).jpg',
#  'PMI(112)',
#  'PMI(112).jpg',
#  'PMI(113)',
#  'PMI(113).jpg',
#  'PMI(114)',
#  'PMI(114).jpg',
#  'PMI(115)',
#  'PMI(115).jpg',
#  'PMI(116)',
#  'PMI(116).jpg',
#  'PMI(117)',
#  'PMI(117).jpg',
#  'PMI(118)',
#  'PMI(118).jpg',
#  'PMI(119)',
#  'PMI(119).jpg',
#  'PMI(120)',
#  'PMI(120).jpg',
#  'PMI(121)',
#  'PMI(121).jpg',
#  'PMI(122)',
#  'PMI(122).jpg',
#  'PMI(123)',
#  'PMI(123).jpg',
#  'PMI(124)',
#  'PMI(124).jpg',
#  'PMI(125)',
#  'PMI(125).jpg',
#  'PMI(126)',
#  'PMI(126).jpg',
#  'PMI(127)',
#  'PMI(127).jpg',
#  'PMI(128)',
#  'PMI(128).jpg',
#  'PMI(129)',
#  'PMI(129).jpg',
#  'PMI(130)',
#  'PMI(130).jpg',
#  'PMI(131)',
#  'PMI(131).jpg',
#  'PMI(132)',
#  'PMI(132).jpg',
#  'PMI(133)',
#  'PMI(133).jpg',
#  'PMI(134)',
#  'PMI(134).jpg',
#  'PMI(135)',
#  'PMI(135).jpg',
#  'PMI(136)',
#  'PMI(136).jpg',
#  'PMI(137)',
#  'PMI(137).jpg',
#  'PMI(138)',
#  'PMI(138).jpg',
#  'PMI(139)',
#  'PMI(139).jpg',
#  'PMI(140)',
#  'PMI(140).jpg',
#  'PMI(141)',
#  'PMI(141).jpg',
#  'PMI(142)',
#  'PMI(142).jpg',
#  'PMI(143)',
#  'PMI(143).jpg',
#  'PMI(144)',
#  'PMI(144).jpg',
#  'PMI(145)',
#  'PMI(145).jpg',
#  'PMI(146)',
#  'PMI(146).jpg',
#  'PMI(147)',
#  'PMI(147).jpg',
#  'PMI(148)',
#  'PMI(148).jpg',
#  'PMI(149)',
#  'PMI(149).jpg',
#  'PMI(150)',
#  'PMI(150).jpg',
#  'PMI(151)',
#  'PMI(151).jpg',
#  'PMI(152)',
#  'PMI(152).jpg',
#  'PMI(153)',
#  'PMI(153).jpg',
#  'PMI(154)',
#  'PMI(154).jpg',
#  'PMI(155)',
#  'PMI(155).jpg',
#  'PMI(156)',
#  'PMI(156).jpg',
#  'PMI(157)',
#  'PMI(157).jpg',
#  'PMI(158)',
#  'PMI(158).jpg',
#  'PMI(159)',
#  'PMI(159).jpg',
#  'PMI(160)',
#  'PMI(160).jpg',
#  'PMI(161)',
#  'PMI(161).jpg',
#  'PMI(162)',
#  'PMI(162).jpg',
#  'PMI(163)',
#  'PMI(163).jpg',
#  'PMI(164)',
#  'PMI(164).jpg',
#  'PMI(165)',
#  'PMI(165).jpg',
#  'PMI(166)',
#  'PMI(166).jpg',
#  'PMI(167)',
#  'PMI(167).jpg',
#  'PMI(168)',
#  'PMI(168).jpg',
#  'PMI(169)',
#  'PMI(169).jpg',
#  'PMI(170)',
#  'PMI(170).jpg',
#  'PMI(171)',
#  'PMI(171).jpg',
#  'PMI(172)',
#  'PMI(172).jpg',
#  'scaled_data_1D_1.csv',
#  'scaled_data_1D_2.csv',
#  'scaled_data_1D_3.csv',
#  'scaled_data_1D_4.csv',
#  'scaled_data_1D_5.csv',
#  'scaled_data_1D_6.csv',
#  'scaled_data_1D_7.csv',
#  'scaled_data_1D_8.csv',
#  'scaled_data_1D_9.csv',
#  'scaled_data_1D_10.csv',
#  'scaled_data_1D_11.csv',
#  'scaled_data_1D_12.csv',
#  'scaled_data_1D_13.csv']

# %%
HB_ = natsorted(HB_)
HB_
# Out:
# ['HB(1)',
#  'HB(1).jpg',
#  'HB(2)',
#  'HB(2).jpg',
#  'HB(3)',
#  'HB(3).jpg',
#  'HB(4)',
#  'HB(4).jpg',
#  'HB(5)',
#  'HB(5).jpg',
#  'HB(6)',
#  'HB(6).jpg',
#  'HB(7)',
#  'HB(7).jpg',
#  'HB(8)',
#  'HB(8).jpg',
#  'HB(9)',
#  'HB(9).jpg',
#  'HB(10)',
#  'HB(10).jpg',
#  'HB(11)',
#  'HB(11).jpg',
#  'HB(12)',
#  'HB(12).jpg',
#  'HB(13)',
#  'HB(13).jpg',
#  'HB(14)',
#  'HB(14).jpg',
#  'HB(15)',
#  'HB(15).jpg',
#  'HB(16)',
#  'HB(16).jpg',
#  'HB(17)',
#  'HB(17).jpg',
#  'HB(18)',
#  'HB(18).jpg',
#  'HB(19)',
#  'HB(19).jpg',
#  'HB(20)',
#  'HB(20).jpg',
#  'HB(21)',
#  'HB(21).jpg',
#  'HB(22)',
#  'HB(22).jpg',
#  'HB(23)',
#  'HB(23).jpg',
#  'HB(24)',
#  'HB(24).jpg',
#  'HB(25)',
#  'HB(25).jpg',
#  'HB(26)',
#  'HB(26).jpg',
#  'HB(27)',
#  'HB(27).jpg',
#  'HB(28)',
#  'HB(28).jpg',
#  'HB(29)',
#  'HB(29).jpg',
#  'HB(30)',
#  'HB(30).jpg',
#  'HB(31)',
#  'HB(31).jpg',
#  'HB(32)',
#  'HB(32).jpg',
#  'HB(33)',
#  'HB(33).jpg',
#  'HB(34)',
#  'HB(34).jpg',
#  'HB(35)',
#  'HB(35).jpg',
#  'HB(36)',
#  'HB(36).jpg',
#  'HB(37)',
#  'HB(37).jpg',
#  'HB(38)',
#  'HB(38).jpg',
#  'HB(39)',
#  'HB(39).jpg',
#  'HB(40)',
#  'HB(40).jpg',
#  'HB(41)',
#  'HB(41).jpg',
#  'HB(42)',
#  'HB(42).jpg',
#  'HB(43)',
#  'HB(43).jpg',
#  'HB(44)',
#  'HB(44).jpg',
#  'HB(45)',
#  'HB(45).jpg',
#  'HB(46)',
#  'HB(46).jpg',
#  'HB(47)',
#  'HB(47).jpg',
#  'HB(48)',
#  'HB(48).jpg',
#  'HB(49)',
#  'HB(49).jpg',
#  'HB(50)',
#  'HB(50).jpg',
#  'HB(51)',
#  'HB(51).jpg',
#  'HB(52)',
#  'HB(52).jpg',
#  'HB(53)',
#  'HB(53).jpg',
#  'HB(54)',
#  'HB(54).jpg',
#  'HB(55)',
#  'HB(55).jpg',
#  'HB(56)',
#  'HB(56).jpg',
#  'HB(57)',
#  'HB(57).jpg',
#  'HB(58)',
#  'HB(58).jpg',
#  'HB(59)',
#  'HB(59).jpg',
#  'HB(60)',
#  'HB(60).jpg',
#  'HB(61)',
#  'HB(61).jpg',
#  'HB(62)',
#  'HB(62).jpg',
#  'HB(63)',
#  'HB(63).jpg',
#  'HB(64)',
#  'HB(64).jpg',
#  'HB(65)',
#  'HB(65).jpg',
#  'HB(66)',
#  'HB(66).jpg',
#  'HB(67)',
#  'HB(67).jpg',
#  'HB(68)',
#  'HB(68).jpg',
#  'HB(69)',
#  'HB(69).jpg',
#  'HB(70)',
#  'HB(70).jpg',
#  'HB(71)',
#  'HB(71).jpg',
#  'HB(72)',
#  'HB(72).jpg',
#  'HB(73)',
#  'HB(73).jpg',
#  'HB(74)',
#  'HB(74).jpg',
#  'HB(75)',
#  'HB(75).jpg',
#  'HB(76)',
#  'HB(76).jpg',
#  'HB(77)',
#  'HB(77).jpg',
#  'HB(78)',
#  'HB(78).jpg',
#  'HB(79)',
#  'HB(79).jpg',
#  'HB(80)',
#  'HB(80).jpg',
#  'HB(81)',
#  'HB(81).jpg',
#  'HB(82)',
#  'HB(82).jpg',
#  'HB(83)',
#  'HB(83).jpg',
#  'HB(84)',
#  'HB(84).jpg',
#  'HB(85)',
#  'HB(85).jpg',
#  'HB(86)',
#  'HB(86).jpg',
#  'HB(87)',
#  'HB(87).jpg',
#  'HB(88)',
#  'HB(88).jpg',
#  'HB(89)',
#  'HB(89).jpg',
#  'HB(90)',
#  'HB(90).jpg',
#  'HB(91)',
#  'HB(91).jpg',
#  'HB(92)',
#  'HB(92).jpg',
#  'HB(93)',
#  'HB(93).jpg',
#  'HB(94)',
#  'HB(94).jpg',
#  'HB(95)',
#  'HB(95).jpg',
#  'HB(96)',
#  'HB(96).jpg',
#  'HB(97)',
#  'HB(97).jpg',
#  'HB(98)',
#  'HB(98).jpg',
#  'HB(99)',
#  'HB(99).jpg',
#  'HB(100)',
#  'HB(100).jpg',
#  'HB(101)',
#  'HB(101).jpg',
#  'HB(102)',
#  'HB(102).jpg',
#  'HB(103)',
#  'HB(103).jpg',
#  'HB(104)',
#  'HB(104).jpg',
#  'HB(105)',
#  'HB(105).jpg',
#  'HB(106)',
#  'HB(106).jpg',
#  'HB(107)',
#  'HB(107).jpg',
#  'HB(108)',
#  'HB(108).jpg',
#  'HB(109)',
#  'HB(109).jpg',
#  'HB(110)',
#  'HB(110).jpg',
#  'HB(111)',
#  'HB(111).jpg',
#  'HB(112)',
#  'HB(112).jpg',
#  'HB(113)',
#  'HB(113).jpg',
#  'HB(114)',
#  'HB(114).jpg',
#  'HB(115)',
#  'HB(115).jpg',
#  'HB(116)',
#  'HB(116).jpg',
#  'HB(117)',
#  'HB(117).jpg',
#  'HB(118)',
#  'HB(118).jpg',
#  'HB(119)',
#  'HB(119).jpg',
#  'HB(120)',
#  'HB(120).jpg',
#  'HB(121)',
#  'HB(121).jpg',
#  'HB(122)',
#  'HB(122).jpg',
#  'HB(123)',
#  'HB(123).jpg',
#  'HB(124)',
#  'HB(124).jpg',
#  'HB(125)',
#  'HB(125).jpg',
#  'HB(126)',
#  'HB(126).jpg',
#  'HB(127)',
#  'HB(127).jpg',
#  'HB(128)',
#  'HB(128).jpg',
#  'HB(129)',
#  'HB(129).jpg',
#  'HB(130)',
#  'HB(130).jpg',
#  'HB(131)',
#  'HB(131).jpg',
#  'HB(132)',
#  'HB(132).jpg',
#  'HB(133)',
#  'HB(133).jpg',
#  'HB(134)',
#  'HB(134).jpg',
#  'HB(135)',
#  'HB(135).jpg',
#  'HB(136)',
#  'HB(136).jpg',
#  'HB(137)',
#  'HB(137).jpg',
#  'HB(138)',
#  'HB(138).jpg',
#  'HB(139)',
#  'HB(139).jpg',
#  'HB(140)',
#  'HB(140).jpg',
#  'HB(141)',
#  'HB(141).jpg',
#  'HB(142)',
#  'HB(142).jpg',
#  'HB(143)',
#  'HB(143).jpg',
#  'HB(144)',
#  'HB(144).jpg',
#  'HB(145)',
#  'HB(145).jpg',
#  'HB(146)',
#  'HB(146).jpg',
#  'HB(147)',
#  'HB(147).jpg',
#  'HB(148)',
#  'HB(148).jpg',
#  'HB(149)',
#  'HB(149).jpg',
#  'HB(150)',
#  'HB(150).jpg',
#  'HB(151)',
#  'HB(151).jpg',
#  'HB(152)',
#  'HB(152).jpg',
#  'HB(153)',
#  'HB(153).jpg',
#  'HB(154)',
#  'HB(154).jpg',
#  'HB(155)',
#  'HB(155).jpg',
#  'HB(156)',
#  'HB(156).jpg',
#  'HB(157)',
#  'HB(157).jpg',
#  'HB(158)',
#  'HB(158).jpg',
#  'HB(159)',
#  'HB(159).jpg',
#  'HB(160)',
#  'HB(160).jpg',
#  'HB(161)',
#  'HB(161).jpg',
#  'HB(162)',
#  'HB(162).jpg',
#  'HB(163)',
#  'HB(163).jpg',
#  'HB(164)',
#  'HB(164).jpg',
#  'HB(165)',
#  'HB(165).jpg',
#  'HB(166)',
#  'HB(166).jpg',
#  'HB(167)',
#  'HB(167).jpg',
#  'HB(168)',
#  'HB(168).jpg',
#  'HB(169)',
#  'HB(169).jpg',
#  'HB(170)',
#  'HB(170).jpg',
#  'HB(171)',
#  'HB(171).jpg',
#  'HB(172)',
#  'HB(172).jpg',
#  'HB(173)',
#  'HB(173).jpg',
#  'HB(174)',
#  'HB(174).jpg',
#  'HB(175)',
#  'HB(175).jpg',
#  'HB(176)',
#  'HB(176).jpg',
#  'HB(177)',
#  'HB(177).jpg',
#  'HB(178)',
#  'HB(178).jpg',
#  'HB(179)',
#  'HB(179).jpg',
#  'HB(180)',
#  'HB(180).jpg',
#  'HB(181)',
#  'HB(181).jpg',
#  'HB(182)',
#  'HB(182).jpg',
#  'HB(183)',
#  'HB(183).jpg',
#  'HB(184)',
#  'HB(184).jpg',
#  'HB(185)',
#  'HB(185).jpg',
#  'HB(186)',
#  'HB(186).jpg',
#  'HB(187)',
#  'HB(187).jpg',
#  'HB(188)',
#  'HB(188).jpg',
#  'HB(189)',
#  'HB(189).jpg',
#  'HB(190)',
#  'HB(190).jpg',
#  'HB(191)',
#  'HB(191).jpg',
#  'HB(192)',
#  'HB(192).jpg',
#  'HB(193)',
#  'HB(193).jpg',
#  'HB(194)',
#  'HB(194).jpg',
#  'HB(195)',
#  'HB(195).jpg',
#  'HB(196)',
#  'HB(196).jpg',
#  'HB(197)',
#  'HB(197).jpg',
#  'HB(198)',
#  'HB(198).jpg',
#  'HB(199)',
#  'HB(199).jpg',
#  'HB(200)',
#  'HB(200).jpg',
#  'HB(201)',
#  'HB(201).jpg',
#  'HB(202)',
#  'HB(202).jpg',
#  'HB(203)',
#  'HB(203).jpg',
#  'HB(204)',
#  'HB(204).jpg',
#  'HB(205)',
#  'HB(205).jpg',
#  'HB(206)',
#  'HB(206).jpg',
#  'HB(207)',
#  'HB(207).jpg',
#  'HB(208)',
#  'HB(208).jpg',
#  'HB(209)',
#  'HB(209).jpg',
#  'HB(210)',
#  'HB(210).jpg',
#  'HB(211)',
#  'HB(211).jpg',
#  'HB(212)',
#  'HB(212).jpg',
#  'HB(213)',
#  'HB(213).jpg',
#  'HB(214)',
#  'HB(214).jpg',
#  'HB(215)',
#  'HB(215).jpg',
#  'HB(216)',
#  'HB(216).jpg',
#  'HB(217)',
#  'HB(217).jpg',
#  'HB(218)',
#  'HB(218).jpg',
#  'HB(219)',
#  'HB(219).jpg',
#  'HB(220)',
#  'HB(220).jpg',
#  'HB(221)',
#  'HB(221).jpg',
#  'HB(222)',
#  'HB(222).jpg',
#  'HB(223)',
#  'HB(223).jpg',
#  'HB(224)',
#  'HB(224).jpg',
#  'HB(225)',
#  'HB(225).jpg',
#  'HB(226)',
#  'HB(226).jpg',
#  'HB(227)',
#  'HB(227).jpg',
#  'HB(228)',
#  'HB(228).jpg',
#  'HB(229)',
#  'HB(229).jpg',
#  'HB(230)',
#  'HB(230).jpg',
#  'HB(231)',
#  'HB(231).jpg',
#  'HB(232)',
#  'HB(232).jpg',
#  'HB(233)',
#  'HB(233).jpg',
#  'scaled_data_1D_1.csv',
#  'scaled_data_1D_2.csv',
#  'scaled_data_1D_3.csv',
#  'scaled_data_1D_4.csv',
#  'scaled_data_1D_5.csv',
#  'scaled_data_1D_6.csv',
#  'scaled_data_1D_7.csv',
#  'scaled_data_1D_8.csv',
#  'scaled_data_1D_9.csv',
#  'scaled_data_1D_10.csv',
#  'scaled_data_1D_11.csv',
#  'scaled_data_1D_12.csv',
#  'scaled_data_1D_13.csv']

# %% [markdown]
# #### **COMBINED CSV OF EACH LEAD(1-12) FROM ALL IMAGES**

# %%
import pandas as pd

#loop over and create combined csv files for each leads.
for x in range(len(MI_)):
    try:
        df1 = pd.read_csv('/content/drive/MyDrive/CardioVision/DataSet/NHB/scaled_data_1D_{}.csv'.format(x + 1))
        df2 = pd.read_csv('/content/drive/MyDrive/CardioVision/DataSet/AHB/scaled_data_1D_{}.csv'.format(x + 1))
        df3 = pd.read_csv('/content/drive/MyDrive/CardioVision/DataSet/MI/scaled_data_1D_{}.csv'.format(x + 1))
        df4 = pd.read_csv('/content/drive/MyDrive/CardioVision/DataSet/PMI/scaled_data_1D_{}.csv'.format(x + 1))
        final_df = pd.concat([df1,df2,df3,df4],ignore_index=True)
        final_df.to_csv('/content/drive/MyDrive/CardioVision/TrainedData/CombinedLead{}.csv'.format(x+1))
    except FileNotFoundError:
        pass # Skip to the next iteration if a file is not found

# %%
#now reading just lead1
df=pd.read_csv('/content/drive/MyDrive/CardioVision/TrainedData/CombinedLead1.csv')
df['Target'].unique()
# Out:
# array(['No', 'HB', 'MI', 'PM'], dtype=object)

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
#convert Target column values as Numeric using ngroups
encode_target_label = df.groupby('Target').ngroup().rename("target").to_frame()
test_final  = df.merge(encode_target_label, left_index=True, right_index=True)
test_final.drop(columns=['Target'],inplace=True)
test_final
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.822643  0.851932  0.830764  0.741948  0.641310  0.537874  0.436175
# 1    0.664750  0.714455  0.734318  0.741968  0.784386  0.814354  0.768086
# 2    0.918868  0.871035  0.843640  0.880725  0.919767  0.928998  0.910694
# 3    0.958754  1.000000  0.945336  0.839421  0.722056  0.612720  0.498574
# 4    0.962030  0.961321  0.947734  0.939844  0.939544  0.935878  0.944975
# ..        ...       ...       ...       ...       ...       ...       ...
# 923  0.916290  0.821394  0.707631  0.607996  0.664757  0.785601  0.878273
# 924  0.710817  0.720143  0.704892  0.617803  0.528379  0.414255  0.327710
# 925  0.792162  0.791956  0.781063  0.783865  0.804423  0.802450  0.856589
# 926  0.785536  0.840841  0.795443  0.809226  0.797815  0.818477  0.795410
# 927  0.834846  0.835026  0.848415  0.850183  0.852194  0.850544  0.852060
#
#             7         8         9  ...       246       247       248  \
# 0    0.441703  0.545023  0.643225  ...  0.065451  0.162277  0.267585
# 1    0.799548  0.761994  0.619581  ...  0.456768  0.606526  0.602687
# 2    0.905488  0.911863  0.912809  ...  0.862596  0.860059  0.859367
# 3    0.498224  0.610510  0.728202  ...  0.076339  0.171428  0.285154
# 4    0.945117  0.944936  0.935101  ...  0.867795  0.868116  0.879961
# ..        ...       ...       ...  ...       ...       ...       ...
# 923  0.898269  0.859869  0.830883  ...  0.430337  0.341215  0.232574
# 924  0.363878  0.465357  0.553734  ...  0.304984  0.210999  0.176200
# 925  0.924024  0.979983  0.949552  ...  0.812842  0.756200  0.685116
# 926  0.827928  0.814306  0.802746  ...  0.594971  0.636016  0.612584
# 927  0.881185  0.913712  0.940417  ...  0.775646  0.731681  0.723865
#
#           249       250       251       252       253       254  target
# 0    0.366791  0.476903  0.578419  0.682183  0.769689  0.777848       2
# 1    0.587123  0.629989  0.599826  0.580095  0.577195  0.532605       2
# 2    0.864370  0.860316  0.811752  0.776486  0.795620  0.831517       2
# 3    0.394616  0.514101  0.623470  0.744910  0.849828  0.869220       2
# 4    0.873809  0.867829  0.869088  0.885836  0.887253  0.886352       2
# ..        ...       ...       ...       ...       ...       ...     ...
# 923  0.109652  0.007965  0.000000  0.106291  0.217261  0.328313       3
# 924  0.258981  0.362836  0.471012  0.563339  0.588311  0.590754       3
# 925  0.652456  0.647200  0.628454  0.633871  0.631601  0.640003       3
# 926  0.612040  0.653075  0.664196  0.611101  0.543578  0.600977       3
# 927  0.718354  0.728084  0.726277  0.690386  0.701059  0.699635       3
#
# [928 rows x 256 columns]

# %% [markdown]
# #### **PERFORM DIMENSIONALITY REDUCTION JUST FOR CHECKING/UNDERSTANDING**

# %%
#just for testing
# Now Perform Dimensionality reduction (PCA) on that Dataframe and check
from sklearn.decomposition import PCA

#do PCA and choose componeents as 100
pca = PCA(n_components=100)
x_pca = pca.fit_transform(test_final.iloc[:,0:-1])
x_pca = pd.DataFrame(x_pca)

# Calculate the variance explained by priciple components
explained_variance = pca.explained_variance_ratio_
print('Variance of each component:', pca.explained_variance_ratio_)
print('\n Total Variance Explained:', round(sum(list(pca.explained_variance_ratio_))*100, 2))

#store the new pca generated dimensions in a dataframe
pca_df = pd.DataFrame(data = x_pca)
target = pd.Series(test_final['target'], name='target')
result_df = pd.concat([pca_df, target], axis=1)
result_df
# Out:
# Variance of each component: [1.76631711e-01 9.47841846e-02 7.00100519e-02 6.14026654e-02
#  5.33383989e-02 4.23623127e-02 3.69098118e-02 3.38745152e-02
#  3.00158981e-02 2.89945688e-02 2.64691913e-02 2.42569640e-02
#  2.11690566e-02 1.99633083e-02 1.77748538e-02 1.62162835e-02
#  1.52721200e-02 1.48309040e-02 1.34418063e-02 1.20062516e-02
#  1.17530896e-02 1.05531342e-02 9.63050847e-03 9.41801238e-03
#  8.64223009e-03 8.47025185e-03 7.91878283e-03 7.30862520e-03
#  6.84760694e-03 6.38087529e-03 5.98449751e-03 5.47038359e-03
#  5.29039352e-03 4.97484057e-03 4.76542228e-03 4.46934342e-03
#  4.23682780e-03 4.00132225e-03 3.82983831e-03 3.52568125e-03
#  3.38250175e-03 3.25792933e-03 3.08591094e-03 3.01371361e-03
#  2.73110840e-03 2.50310601e-03 2.36348041e-03 2.27449529e-03
#  2.18960064e-03 1.99106312e-03 1.73887639e-03 1.70320722e-03
#  1.57079343e-03 1.50915169e-03 1.38122660e-03 1.32580398e-03
#  1.26115946e-03 1.18773619e-03 1.17785245e-03 1.09298665e-03
#  1.02856003e-03 9.21386903e-04 7.92491113e-04 7.71182408e-04
#  6.49755056e-04 6.22135582e-04 6.05545238e-04 5.49402227e-04
#  5.33573428e-04 4.83661466e-04 4.74732127e-04 4.49183911e-04
#  4.32753528e-04 4.09160744e-04 3.95604748e-04 3.71414705e-04
#  3.55188502e-04 3.37060805e-04 3.05051439e-04 2.96587599e-04
#  2.79140137e-04 2.64923020e-04 2.45988884e-04 2.37435727e-04
#  2.13299522e-04 1.99891273e-04 1.95898938e-04 1.86586473e-04
#  1.66953841e-04 1.62157289e-04 1.56784662e-04 1.40730510e-04
#  1.24966249e-04 1.21298418e-04 1.13812507e-04 1.09648254e-04
#  1.01413006e-04 9.95736734e-05 9.67574201e-05 9.09962929e-05]
#
#  Total Variance Explained: 99.8
#             0         1         2         3         4         5         6  \
# 0   -1.162418  0.037913  1.612489 -1.261841 -0.142678  0.906283  0.773153
# 1    1.348048 -0.468704  0.220905 -0.603076  0.138712  0.118985  0.142934
# 2   -1.652148 -0.839159  0.117576 -1.313716 -0.492334  0.741324 -0.941959
# 3   -1.339560 -0.057861  1.199583 -0.162102 -0.583947  1.442121  0.988157
# 4   -1.768674 -0.542499  0.327701 -0.417646 -0.368101  1.123794 -1.137381
# ..        ...       ...       ...       ...       ...       ...       ...
# 923 -0.521480 -1.598209 -0.365344  0.754929 -0.345171  0.493356 -0.072591
# 924  1.869540  0.103546 -0.448084 -0.424458 -0.292475  0.043122  0.487807
# 925 -0.166327  1.199951 -0.124719  0.018071  0.013341  0.067898 -0.286475
# 926 -0.113592  0.575571 -0.249600 -0.326467 -0.274789  0.192019  0.052260
# 927 -1.102371  1.278477 -0.331359 -0.922451  0.158848  0.131820  0.004359
#
#             7         8         9  ...        91        92        93  \
# 0   -0.997150  0.322555  0.970770  ... -0.051397  0.099177 -0.024578
# 1   -0.039512  0.352271 -0.131305  ...  0.011771  0.037934  0.175229
# 2   -0.703226  0.648772 -0.178943  ... -0.017292 -0.012386 -0.015013
# 3    0.220954 -0.011325  0.767378  ... -0.046187  0.001902 -0.030132
# 4   -0.317882  0.150756 -0.569931  ... -0.011421 -0.047179  0.022629
# ..        ...       ...       ...  ...       ...       ...       ...
# 923 -0.183976  0.942369  0.200510  ... -0.044064  0.111223  0.043406
# 924 -0.004323  0.415090 -0.460163  ...  0.052639 -0.077459  0.075019
# 925  0.024602  0.602304 -0.791678  ...  0.005479 -0.017787 -0.022967
# 926 -0.398704  0.842755 -0.117805  ...  0.065013  0.015612 -0.051685
# 927 -0.547190  0.617257 -0.391317  ...  0.064920 -0.011158  0.061891
#
#            94        95        96        97        98        99  target
# 0    0.015024 -0.011168  0.014086 -0.010871  0.003375 -0.052276       2
# 1    0.135574 -0.019292  0.028172 -0.007333 -0.007547  0.012742       2
# 2    0.001058  0.004200  0.005923 -0.021499  0.032434  0.022479       2
# 3    0.027740  0.026267  0.010023  0.006864 -0.061032 -0.025216       2
# 4    0.002564 -0.041068 -0.023830 -0.009244 -0.031151  0.000635       2
# ..        ...       ...       ...       ...       ...       ...     ...
# 923 -0.006142 -0.034079 -0.043236 -0.078035  0.006148  0.075592       3
# 924 -0.036505  0.033205  0.056487  0.005269 -0.008145 -0.020009       3
# 925 -0.005299  0.019051 -0.006586  0.010085  0.026474 -0.005898       3
# 926 -0.012146  0.013265  0.043012  0.031558  0.029671  0.028435       3
# 927 -0.012367 -0.071557 -0.041644 -0.013851  0.022510  0.010118       3
#
# [928 rows x 101 columns]

# %% [markdown]
# #### **TRYING DIFFERENT ML MODELS ON A SINGLE LEAD(EX : 1) POST DIMENSIONALITY REDUCTION**

# %% [markdown]
# ##### **KNN**

# %%
# Import the necessary modules for ML model
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report

# Setup the pipeline steps:
steps = [('knn', KNeighborsClassifier())]

# Create the pipeline: pipeline
pipeline = Pipeline(steps)

# have paased less range value of hyperparamter since i'm using free tier version of google colab.
k_range = list(range(1, 9))
parameters = dict(knn__n_neighbors=k_range)

#input
X = result_df.iloc[:,0:-1]

#target
y=result_df.iloc[:,-1]

# Create train and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.4,random_state=42)

#increasing cv score takes lot of time in gooogle colab, so kept it just 2.
cv = GridSearchCV(pipeline,parameters,cv=2)

cv.fit(X_train,y_train)

# Predict the labels of the test set: y_pred
y_pred = cv.predict(X_test)

Knn_Accuracy = cv.score(X_test, y_test)

# Compute and print metrics
print("Accuracy: {}".format(Knn_Accuracy))
print(classification_report(y_test, y_pred))
print("Tuned Model Parameters: {}".format(cv.best_params_))
# Out:
# Accuracy: 0.8494623655913979
#               precision    recall  f1-score   support
#
#            0       0.87      0.64      0.74       105
#            1       0.99      1.00      0.99        94
#            2       0.84      0.91      0.88       112
#            3       0.67      0.87      0.76        61
#
#     accuracy                           0.85       372
#    macro avg       0.84      0.85      0.84       372
# weighted avg       0.86      0.85      0.85       372
#
# Tuned Model Parameters: {'knn__n_neighbors': 1}

# %% [markdown]
# ##### **LOGISTIC REGRESSION**

# %%
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report

# Setup the pipeline steps with scaling:
steps = [
    ('scaler', StandardScaler()),  # Adding a scaler to normalize the data
    ('lr', LogisticRegression(max_iter=1000))  # Increase max_iter
]

# Create the pipeline: pipeline
pipeline = Pipeline(steps)

# Input
X = result_df.iloc[:, 0:-1]

# Target
y = result_df.iloc[:, -1]

# Parameters for GridSearchCV
c_space = np.logspace(-4, 4, 3)
parameters = {'lr__C': c_space, 'lr__penalty': ['l2']}

# Create train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# Call GridSearchCV and set cross-validation to 2
cv = GridSearchCV(pipeline, parameters, cv=2)

# Fit the model
cv.fit(X_train, y_train)

# Predict the labels of the test set
y_pred = cv.predict(X_test)

# Calculate accuracy
LR_Accuracy = cv.score(X_test, y_test)

# %%
# Compute and print metrics
print("Accuracy: {}".format(LR_Accuracy))
print(classification_report(y_test, y_pred))
print("Tuned Model Parameters: {}".format(cv.best_params_))
# Out:
# Accuracy: 0.6317204301075269
#               precision    recall  f1-score   support
#
#            0       0.62      0.38      0.47       105
#            1       0.79      1.00      0.88        94
#            2       0.65      0.63      0.64       112
#            3       0.38      0.49      0.43        61
#
#     accuracy                           0.63       372
#    macro avg       0.61      0.63      0.61       372
# weighted avg       0.63      0.63      0.62       372
#
# Tuned Model Parameters: {'lr__C': 1.0, 'lr__penalty': 'l2'}

# %% [markdown]
# ##### **SVM**

# %%
# Import the necessary modules for ML model
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report

# Setup the pipeline
steps = [('SVM', SVC())]

pipeline = Pipeline(steps)

#input
X = result_df.iloc[:,0:-1]

#target
y=result_df.iloc[:,-1]

# Specify the hyperparameter space, if we increase the penalty(c) and gamma value the accurancy can be increased.
#since it takes lots of time in google colab provided only a single value
parameters = {'SVM__C':[10],'SVM__gamma':[1]}

# Create train and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.4,random_state=21)

cv = GridSearchCV(pipeline,parameters,cv=3)
cv.fit(X_train,y_train)

y_pred = cv.predict(X_test)
SVM_Accuracy = cv.score(X_test, y_test)

# Compute and print metrics
SVM_Accuracy=cv.score(X_test, y_test)

print("Accuracy: {}".format(SVM_Accuracy))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8145161290322581
#               precision    recall  f1-score   support
#
#            0       0.58      0.99      0.73        93
#            1       1.00      1.00      1.00        99
#            2       0.96      0.64      0.77       117
#            3       1.00      0.59      0.74        63
#
#     accuracy                           0.81       372
#    macro avg       0.89      0.80      0.81       372
# weighted avg       0.88      0.81      0.82       372

# %% [markdown]
# #### **NOW COMBINING ALL 12 LEADS INTO A SINGLE CSV FILE AND THEN PERFROM MODEL ANALYSIS**

# %%
#lets try combining all 12 leads in a single csv
location= '/content/drive/MyDrive/CardioVision/DataSet/'
for files in natsorted(os.listdir(location)):
  if files.endswith(".csv") and not files.endswith("13.csv"):
    if files!='Combined_IDLead_1.csv':
      df=pd.read_csv('/content/drive/MyDrive/CardioVision/DataSet/{}'.format(files))
      df.drop(columns=['Unnamed: 0'],inplace=True)
      test_final=pd.concat([test_final,df],axis=1,ignore_index=True)
      test_final.drop(columns=test_final.columns[-1],axis=1,inplace=True)

#drop the target column
test_final.drop(columns=test_final.columns[-1],axis=1,inplace=True)
test_final
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.822643  0.851932  0.830764  0.741948  0.641310  0.537874  0.436175
# 1    0.664750  0.714455  0.734318  0.741968  0.784386  0.814354  0.768086
# 2    0.918868  0.871035  0.843640  0.880725  0.919767  0.928998  0.910694
# 3    0.958754  1.000000  0.945336  0.839421  0.722056  0.612720  0.498574
# 4    0.962030  0.961321  0.947734  0.939844  0.939544  0.935878  0.944975
# ..        ...       ...       ...       ...       ...       ...       ...
# 923  0.916290  0.821394  0.707631  0.607996  0.664757  0.785601  0.878273
# 924  0.710817  0.720143  0.704892  0.617803  0.528379  0.414255  0.327710
# 925  0.792162  0.791956  0.781063  0.783865  0.804423  0.802450  0.856589
# 926  0.785536  0.840841  0.795443  0.809226  0.797815  0.818477  0.795410
# 927  0.834846  0.835026  0.848415  0.850183  0.852194  0.850544  0.852060
#
#             7         8         9  ...       245       246       247  \
# 0    0.441703  0.545023  0.643225  ...  0.000000  0.065451  0.162277
# 1    0.799548  0.761994  0.619581  ...  0.265213  0.456768  0.606526
# 2    0.905488  0.911863  0.912809  ...  0.859403  0.862596  0.860059
# 3    0.498224  0.610510  0.728202  ...  0.077823  0.076339  0.171428
# 4    0.945117  0.944936  0.935101  ...  0.867795  0.867795  0.868116
# ..        ...       ...       ...  ...       ...       ...       ...
# 923  0.898269  0.859869  0.830883  ...  0.548376  0.430337  0.341215
# 924  0.363878  0.465357  0.553734  ...  0.405330  0.304984  0.210999
# 925  0.924024  0.979983  0.949552  ...  0.796766  0.812842  0.756200
# 926  0.827928  0.814306  0.802746  ...  0.623390  0.594971  0.636016
# 927  0.881185  0.913712  0.940417  ...  0.827566  0.775646  0.731681
#
#           248       249       250       251       252       253       254
# 0    0.267585  0.366791  0.476903  0.578419  0.682183  0.769689  0.777848
# 1    0.602687  0.587123  0.629989  0.599826  0.580095  0.577195  0.532605
# 2    0.859367  0.864370  0.860316  0.811752  0.776486  0.795620  0.831517
# 3    0.285154  0.394616  0.514101  0.623470  0.744910  0.849828  0.869220
# 4    0.879961  0.873809  0.867829  0.869088  0.885836  0.887253  0.886352
# ..        ...       ...       ...       ...       ...       ...       ...
# 923  0.232574  0.109652  0.007965  0.000000  0.106291  0.217261  0.328313
# 924  0.176200  0.258981  0.362836  0.471012  0.563339  0.588311  0.590754
# 925  0.685116  0.652456  0.647200  0.628454  0.633871  0.631601  0.640003
# 926  0.612584  0.612040  0.653075  0.664196  0.611101  0.543578  0.600977
# 927  0.723865  0.718354  0.728084  0.726277  0.690386  0.701059  0.699635
#
# [928 rows x 255 columns]

# %%
#write the final file to csv
test_final.to_csv('final_1D.csv',header=False,index=False)

# %% [markdown]
# #### **TEST DIMENSIONALITY REDUCTION EXPLAINED VARIANCE ON  THE DATA**

# %%
from sklearn.decomposition import PCA

# Determine the maximum number of components
n_samples = test_final.shape[0]  # Number of samples
n_features = test_final.shape[1]  # Number of features
max_components = min(n_samples, n_features)

# Choose the number of components (cannot exceed max_components)
n_components = min(400, max_components)

# Perform PCA with the appropriate number of components
pca = PCA(n_components=n_components)
x_pca = pca.fit_transform(test_final)
x_pca = pd.DataFrame(x_pca)

# Calculate the variance explained by principal components
explained_variance = pca.explained_variance_ratio_
print('Variance of each component:', pca.explained_variance_ratio_)
print('\n Total Variance Explained:', round(sum(list(pca.explained_variance_ratio_))*100, 2))

# Store the new PCA generated dimensions in a dataframe
pca_df = pd.DataFrame(data=x_pca)
target = pd.Series(result_df.iloc[:, -1], name='target')
final_result_df = pd.concat([pca_df, target], axis=1)
final_result_df
# Out:
# Variance of each component: [1.76631711e-01 9.47841846e-02 7.00100519e-02 6.14026654e-02
#  5.33383989e-02 4.23623127e-02 3.69098118e-02 3.38745152e-02
#  3.00158981e-02 2.89945688e-02 2.64691913e-02 2.42569640e-02
#  2.11690566e-02 1.99633083e-02 1.77748538e-02 1.62162835e-02
#  1.52721200e-02 1.48309040e-02 1.34418063e-02 1.20062516e-02
#  1.17530896e-02 1.05531342e-02 9.63050847e-03 9.41801238e-03
#  8.64223009e-03 8.47025185e-03 7.91878283e-03 7.30862520e-03
#  6.84760694e-03 6.38087529e-03 5.98449751e-03 5.47038359e-03
#  5.29039352e-03 4.97484057e-03 4.76542228e-03 4.46934342e-03
#  4.23682780e-03 4.00132225e-03 3.82983831e-03 3.52568125e-03
#  3.38250175e-03 3.25792933e-03 3.08591094e-03 3.01371361e-03
#  2.73110840e-03 2.50310601e-03 2.36348041e-03 2.27449529e-03
#  2.18960064e-03 1.99106312e-03 1.73887639e-03 1.70320722e-03
#  1.57079343e-03 1.50915169e-03 1.38122660e-03 1.32580398e-03
#  1.26115946e-03 1.18773619e-03 1.17785245e-03 1.09298665e-03
#  1.02856003e-03 9.21386903e-04 7.92491113e-04 7.71182408e-04
#  6.49755057e-04 6.22135582e-04 6.05545238e-04 5.49402227e-04
#  5.33573429e-04 4.83661469e-04 4.74732129e-04 4.49183916e-04
#  4.32753530e-04 4.09160747e-04 3.95604750e-04 3.71414719e-04
#  3.55188518e-04 3.37060914e-04 3.05051451e-04 2.96587671e-04
#  2.79140266e-04 2.64923296e-04 2.45988967e-04 2.37436178e-04
#  2.13301062e-04 1.99891801e-04 1.95899743e-04 1.86587416e-04
#  1.66968038e-04 1.62160171e-04 1.56790314e-04 1.40746079e-04
#  1.25038372e-04 1.21342332e-04 1.13868851e-04 1.09744782e-04
#  1.02615302e-04 9.97319876e-05 9.73180846e-05 9.11562688e-05
#  8.79178640e-05 8.05254584e-05 7.28922653e-05 7.05639711e-05
#  6.99461245e-05 6.67122373e-05 6.26597509e-05 6.09021354e-05
#  5.93980105e-05 5.46729173e-05 5.23459170e-05 4.92509926e-05
#  4.59502093e-05 4.17784221e-05 4.08685294e-05 3.97537055e-05
#  3.86083596e-05 3.68391496e-05 3.54772254e-05 3.42761446e-05
#  3.12464941e-05 3.10199869e-05 2.93788475e-05 2.90266085e-05
#  2.70742545e-05 2.64204669e-05 2.41892539e-05 2.39912086e-05
#  2.28856723e-05 2.18908490e-05 2.08273127e-05 2.04900844e-05
#  1.92971557e-05 1.91442283e-05 1.81137571e-05 1.72185526e-05
#  1.69298474e-05 1.60188508e-05 1.58819276e-05 1.51260715e-05
#  1.46891347e-05 1.34043190e-05 1.32817089e-05 1.28810339e-05
#  1.19242959e-05 1.18435305e-05 1.14814502e-05 1.09522812e-05
#  1.04800853e-05 1.01724042e-05 9.70685851e-06 9.60426400e-06
#  9.20902982e-06 9.02084237e-06 8.63182160e-06 8.33583957e-06
#  7.92293203e-06 7.74565906e-06 7.41616199e-06 7.35659322e-06
#  7.07104464e-06 6.78192036e-06 6.64436311e-06 6.35590261e-06
#  6.08453934e-06 6.05553298e-06 5.61666744e-06 5.52297664e-06
#  5.34445363e-06 5.18222092e-06 5.04434067e-06 4.87883313e-06
#  4.63844862e-06 4.48530074e-06 4.43775241e-06 4.30796536e-06
#  4.29059485e-06 4.15927980e-06 3.84838233e-06 3.82073895e-06
#  3.77413114e-06 3.58674504e-06 3.46839919e-06 3.42547887e-06
#  3.37482754e-06 3.23497983e-06 3.05793855e-06 3.02569459e-06
#  2.85957499e-06 2.79754589e-06 2.65541930e-06 2.55754213e-06
#  2.52625326e-06 2.36139820e-06 2.30941786e-06 2.27829850e-06
#  2.24811692e-06 2.11822462e-06 2.01949110e-06 1.95444997e-06
#  1.94290921e-06 1.84597211e-06 1.78640661e-06 1.76104372e-06
#  1.73413101e-06 1.64394234e-06 1.60743952e-06 1.59566644e-06
#  1.56162367e-06 1.53103750e-06 1.49050144e-06 1.46763997e-06
#  1.40513516e-06 1.32357267e-06 1.26886341e-06 1.25393798e-06
#  1.20683188e-06 1.19448398e-06 1.16738192e-06 1.13463745e-06
#  1.10837785e-06 1.08080394e-06 1.04868127e-06 1.01198076e-06
#  9.83546832e-07 9.69066724e-07 8.99714455e-07 8.79065424e-07
#  8.49332418e-07 8.28158733e-07 8.03443195e-07 7.71759466e-07
#  7.54994190e-07 7.09673175e-07 6.89391943e-07 6.71376162e-07
#  6.43937462e-07 6.32055075e-07 6.02732458e-07 5.89974523e-07
#  5.79910195e-07 5.47413566e-07 5.35302731e-07 5.16691310e-07
#  4.94730313e-07 4.85029934e-07 4.62482969e-07 4.52095727e-07
#  4.30167412e-07 3.74672451e-07 3.66313728e-07 3.37580491e-07
#  3.22547606e-07 3.04045667e-07 2.53600425e-07]
#
#  Total Variance Explained: 100.0
#             0         1         2         3         4         5         6  \
# 0   -1.162418  0.037913  1.612489 -1.261841 -0.142678  0.906283  0.773153
# 1    1.348048 -0.468704  0.220905 -0.603076  0.138712  0.118985  0.142934
# 2   -1.652148 -0.839159  0.117576 -1.313716 -0.492334  0.741324 -0.941959
# 3   -1.339560 -0.057861  1.199583 -0.162102 -0.583947  1.442121  0.988157
# 4   -1.768674 -0.542499  0.327701 -0.417646 -0.368101  1.123794 -1.137381
# ..        ...       ...       ...       ...       ...       ...       ...
# 923 -0.521480 -1.598209 -0.365344  0.754929 -0.345171  0.493356 -0.072591
# 924  1.869540  0.103546 -0.448084 -0.424458 -0.292475  0.043122  0.487807
# 925 -0.166327  1.199951 -0.124719  0.018071  0.013341  0.067898 -0.286475
# 926 -0.113592  0.575571 -0.249600 -0.326467 -0.274789  0.192019  0.052260
# 927 -1.102371  1.278477 -0.331359 -0.922451  0.158848  0.131820  0.004359
#
#             7         8         9  ...       246       247       248  \
# 0   -0.997150  0.322555  0.970770  ...  0.000065 -0.002889 -0.001673
# 1   -0.039512  0.352271 -0.131305  ... -0.001435  0.001429 -0.002619
# 2   -0.703226  0.648772 -0.178943  ... -0.001172 -0.001677 -0.000959
# 3    0.220954 -0.011325  0.767378  ... -0.001772  0.000806  0.002334
# 4   -0.317882  0.150756 -0.569931  ... -0.001495  0.001922 -0.000579
# ..        ...       ...       ...  ...       ...       ...       ...
# 923 -0.183976  0.942369  0.200510  ...  0.002758  0.002957  0.000646
# 924 -0.004323  0.415090 -0.460163  ...  0.001170  0.000859 -0.000543
# 925  0.024602  0.602304 -0.791678  ... -0.001844 -0.002218 -0.004060
# 926 -0.398704  0.842755 -0.117805  ...  0.000811  0.000237 -0.000211
# 927 -0.547190  0.617257 -0.391317  ...  0.000362  0.000202 -0.002546
#
#           249       250       251       252       253       254  target
# 0    0.002394  0.001191 -0.000286  0.001035  0.003997  0.000101       2
# 1   -0.000270  0.000929  0.000497 -0.000902  0.001477 -0.001506       2
# 2   -0.000977 -0.000200  0.000661 -0.000240  0.002379 -0.003108       2
# 3    0.001866  0.002577  0.001434  0.000021  0.000066  0.000145       2
# 4    0.002172 -0.001233 -0.003662 -0.000134  0.002131  0.000773       2
# ..        ...       ...       ...       ...       ...       ...     ...
# 923  0.000978  0.000198  0.003395 -0.001039 -0.001159 -0.002185       3
# 924  0.000466 -0.000700  0.000223  0.000786  0.001559 -0.000006       3
# 925  0.002629 -0.000563  0.000445  0.000473 -0.001104 -0.001157       3
# 926 -0.001089  0.001823  0.000157  0.001075 -0.000027 -0.000829       3
# 927  0.000451 -0.002268 -0.002622  0.002617 -0.001415  0.001371       3
#
# [928 rows x 256 columns]

# %%
#save to dimensionally reduced csv file
final_result_df.to_csv("pca_final.csv")

# %%
import joblib
#save the PCA model
joblib_file='PCA_ECG.pkl'
joblib.dump(pca,joblib_file)
# Out:
# ['PCA_ECG.pkl']

# %% [markdown]
# #### **TRYING DIFFERENT ML MODELS ON THE ALL 12 LEADS COMBINED FILE WITHOUT DIMENSIONALITY REDUCTION**

# %% [markdown]
# ##### **KNN**

# %%
# Import the necessary modules for ML model
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report

# Setup the pipeline steps:
steps = [('knn', KNeighborsClassifier())]

# Create the pipeline: pipeline
pipeline = Pipeline(steps)

# have paased less range value of hyperparamter since i'm using free tier version of google colab.
k_range = list(range(1, 30))
parameters = dict(knn__n_neighbors=k_range)

#input
X = final_result_df.iloc[:,:-1]

#target
y=final_result_df.iloc[:,-1]

# Create train and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.4,random_state=42)

#increasing cv score takes lot of time in gooogle colab, so kept it just 2.
cv = GridSearchCV(pipeline,parameters,cv=2)

cv.fit(X_train,y_train)

# Predict the labels of the test set: y_pred
y_pred = cv.predict(X_test)

Knn_Accuracy = cv.score(X_test, y_test)

# Compute and print metrics
print("KNN Accuracy: {}".format(Knn_Accuracy))
print(classification_report(y_test, y_pred))
print("Tuned Model Parameters: {}".format(cv.best_params_))
# Out:
# KNN Accuracy: 0.8494623655913979
#               precision    recall  f1-score   support
#
#            0       0.87      0.64      0.74       105
#            1       0.99      1.00      0.99        94
#            2       0.84      0.91      0.88       112
#            3       0.67      0.87      0.76        61
#
#     accuracy                           0.85       372
#    macro avg       0.84      0.85      0.84       372
# weighted avg       0.86      0.85      0.85       372
#
# Tuned Model Parameters: {'knn__n_neighbors': 1}

# %% [markdown]
# ##### **LOGISTIC REGRESSION**

# %%
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix, classification_report

# Setup the pipeline steps with scaling, PCA, and a different solver
steps = [
    ('scaler', StandardScaler()),  # Adding a scaler to normalize the data
    ('pca', PCA(n_components=0.95)),  # Optionally reduce dimensions, keeping 95% variance
    ('lr', LogisticRegression(max_iter=2000, solver='liblinear'))  # Increase max_iter and change solver
]

# Create the pipeline: pipeline
pipeline = Pipeline(steps)

# Input
X = final_result_df.iloc[:, :-1]

# Target
y = final_result_df.iloc[:, -1]

# Parameters for GridSearchCV
c_space = np.logspace(-4, 4, 10)
parameters = {'lr__C': c_space, 'lr__penalty': ['l2']}  # Keeping l2 penalty, supported by liblinear

# Create train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# Call GridSearchCV and set cross-validation to 2
cv = GridSearchCV(pipeline, parameters, cv=2)

# Fit the model
cv.fit(X_train, y_train)

# Predict the labels of the test set
y_pred = cv.predict(X_test)

# Calculate accuracy
LR_Accuracy = cv.score(X_test, y_test)

# %%
# Output accuracy and classification report
print("Logistic Regression Accuracy:", LR_Accuracy)
print(classification_report(y_test, y_pred))
print("Tuned Model Parameters: {}".format(cv.best_params_))
# Out:
# Logistic Regression Accuracy: 0.739247311827957
#               precision    recall  f1-score   support
#
#            0       0.83      0.38      0.52       105
#            1       0.82      1.00      0.90        94
#            2       0.72      0.89      0.80       112
#            3       0.58      0.67      0.62        61
#
#     accuracy                           0.74       372
#    macro avg       0.74      0.74      0.71       372
# weighted avg       0.75      0.74      0.72       372
#
# Tuned Model Parameters: {'lr__C': 21.54434690031882, 'lr__penalty': 'l2'}

# %% [markdown]
# ##### **SVM**

# %%
# Import the necessary modules for ML model
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report

# Setup the pipeline
steps = [('SVM', SVC())]

pipeline = Pipeline(steps)

#input
X = final_result_df.iloc[:,:-1]

#target
y=final_result_df.iloc[:,-1]

# Specify the hyperparameter space, if we increase the penalty(c) and gamma value the accurancy can be increased.
#since it takes lots of time in google colab provided only a single value
parameters = {'SVM__C':[1, 10, 100],
              'SVM__gamma':[0.1, 0.01]}

# Create train and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.5,random_state=21)

cv = GridSearchCV(pipeline,parameters,cv=3)
cv.fit(X_train,y_train)

y_pred = cv.predict(X_test)
SVM_Accuracy = cv.score(X_test, y_test)

# Compute and print metrics
SVM_Accuracy=cv.score(X_test, y_test)

print("SVM Accuracy: {}".format(SVM_Accuracy))
print(classification_report(y_test, y_pred))
print("Tuned Model Parameters: {}".format(cv.best_params_))
# Out:
# SVM Accuracy: 0.834051724137931
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.79       119
#            1       0.93      1.00      0.97       125
#            2       0.86      0.81      0.84       140
#            3       0.68      0.68      0.68        80
#
#     accuracy                           0.83       464
#    macro avg       0.82      0.82      0.82       464
# weighted avg       0.83      0.83      0.83       464
#
# Tuned Model Parameters: {'SVM__C': 10, 'SVM__gamma': 0.1}

# %% [markdown]
# ### **XGBOOST**

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

model = XGBClassifier()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]

# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("XGBOOST Accuracy: {}".format(accuracy))
print(classification_report(y_test, y_pred))
# Out:
# XGBOOST Accuracy: 0.8125
#               precision    recall  f1-score   support
#
#            0       0.69      0.74      0.71       119
#            1       0.98      1.00      0.99       125
#            2       0.78      0.79      0.78       140
#            3       0.79      0.68      0.73        80
#
#     accuracy                           0.81       464
#    macro avg       0.81      0.80      0.80       464
# weighted avg       0.81      0.81      0.81       464

# %% [markdown]
# #### **SAVING A VERY BASIC ML MODEL AND USING IT ON REALTIME PIPELINE TO CHECK WORKING**

# %%
# Import the necessary modules for ML model
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report
import joblib
#input
X = final_result_df.iloc[:,:-1]
#target
y=final_result_df.iloc[:,-1]

# Create train and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.4,random_state=42)

knn =  KNeighborsClassifier(n_neighbors=1)

knn.fit(X_train,y_train)

joblib_file='knn_model_test.pkl'
joblib.dump(knn,joblib_file)
# Out:
# ['knn_model_test.pkl']

# %%
# Import the necessary modules for ML model
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report

#input
X = pd.read_csv('final_1D.csv',header=None)

#target
y=final_result_df.iloc[:,-1]

# Create train and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.5,random_state=21)

svm=SVC(C=10,gamma=0.01)

svm.fit(X_train,y_train)

joblib_file='svm_model_test.pkl'
joblib.dump(svm,joblib_file)
# Out:
# ['svm_model_test.pkl']

# %% [markdown]
# ### **ENSEMBLE**

# %%
# Importing required modules
from sklearn import linear_model, tree, ensemble
from sklearn.naive_bayes import GaussianNB
import xgboost
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score
import pickle

# %%
#input
X = final_result_df.iloc[:,0:-1]

#target
y=final_result_df.iloc[:,-1]

# Create train and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
# Stacking of ML Models
eclf = VotingClassifier(estimators=[
    ('SVM', SVC(probability=True)),
    ('knn', KNeighborsClassifier()),
    ('rf', ensemble.RandomForestClassifier()),
    ('bayes',GaussianNB()),
    ('logistic',LogisticRegression()),
    ], voting='soft')

# %%
# Hyperparameter Tuning using gridSearch
params = {'SVM__C':[1, 10, 100],
          'SVM__gamma':[0.1, 0.01],
          'knn__n_neighbors': [1,3,5],
          'rf__n_estimators':[300, 400],
          }

grid = GridSearchCV(estimator=eclf, param_grid=params, cv=5)
voting_clf = grid.fit(X_train, y_train)

print(grid.best_params_)
y_pred = voting_clf.predict(X_test)

# Compute and print metrics
Voting_Accuracy=voting_clf.score(X_test, y_test)

print("Ensemble Accuracy: {}".format(Voting_Accuracy))
print(classification_report(y_test, y_pred))
print(voting_clf.best_params_)
# Out:
# {'SVM__C': 100, 'SVM__gamma': 0.1, 'knn__n_neighbors': 1, 'rf__n_estimators': 400}
# Ensemble Accuracy: 0.9139784946236559
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89        80
#            1       1.00      1.00      1.00        72
#            2       0.88      0.95      0.91        79
#            3       0.86      0.79      0.83        48
#
#     accuracy                           0.91       279
#    macro avg       0.91      0.90      0.91       279
# weighted avg       0.91      0.91      0.91       279
#
# {'SVM__C': 100, 'SVM__gamma': 0.1, 'knn__n_neighbors': 1, 'rf__n_estimators': 400}

# %%
# open a file, where you ant to store the data
file = open('Heart_Disease_Prediction_using_ECG.pkl', 'wb')
# dump information to that file
pickle.dump(voting_clf, file)
